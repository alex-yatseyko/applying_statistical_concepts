# %% [markdown]
# ## Ukraine Cities Population

# %%
import pandas as pd

df = pd.read_csv('Ukraine_Major_City_Population.csv')

df
# Out:
#          City  Year Population
# 0        Kyiv  2023  3,017,000
# 1        Kyiv  2022  3,010,000
# 2        Kyiv  2021  3,001,000
# 3        Kyiv  2020  2,988,000
# 4        Kyiv  2019  2,973,000
# ..        ...   ...        ...
# 957  Vinnitsa  1954    165,000
# 958  Vinnitsa  1953    160,000
# 959  Vinnitsa  1952    156,000
# 960  Vinnitsa  1951    152,000
# 961  Vinnitsa  1950    148,000
#
# [962 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

cities = df['City'].unique()

#df['Population'] = pd.to_numeric(df['Population'].str.replace(',', '').astype(int))

for city in cities:
    city_data = df[df['City'] == city]
    plt.plot(city_data['Year'], city_data['Population'], marker='o', linestyle='-', label=city)

max_population = df['Population'].max()


plt.xlabel('Year')
plt.ylabel('Population')
plt.yticks(range(0, max_population, 1000000), rotation=45)

plt.title('Population Trends of Cities')
plt.legend()

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
# The graph above is not really representative. Too many cities and lines.
# Let's focus on Kyiv in the beginning and compare it to Kharkiv and Odesa for example

kyiv = df[df['City'] == 'Kyiv']
kharkiv = df[df['City'] == 'Kharkiv']
odesa = df[df['City'] == 'Odesa']

plt.plot(kyiv['Year'], kyiv['Population'], marker='o', linestyle='-', label='Kyiv')
plt.plot(kharkiv['Year'], kharkiv['Population'], marker='o', linestyle='-', label='Kharkiv')
plt.plot(odesa['Year'], odesa['Population'], marker='o', linestyle='-', label='Odesa')

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Trends of Cities')
plt.legend()

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
# So I can see there are some bad values. I need to clean the data
# Let's check the data for Kyiv

plt.plot(kyiv['Year'], kyiv['Population'], marker='o', linestyle='-', label='Kyiv')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Trends of Cities')
plt.legend()

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
# OH, the graph is bad because population is mirrored in legend. Also there is problem with showing too many years in legend
# Let's fix it

plt.plot(kyiv['Year'], kyiv['Population'], marker='o', linestyle='-', label='Kyiv')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Trends of Cities')
plt.legend()
plt.gca().invert_yaxis()
plt.yticks(kyiv['Population'][::6], rotation=45)

plt.grid(True)
plt.tight_layout()

plt.show()
